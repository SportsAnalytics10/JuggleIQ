# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/satyabratadas10/cv-server/video_processor.py
# /kaggle/input/datasets/satyabratadas10/cv-server/main.py

# %%
# !pip install fastapi uvicorn python-multipart pyngrok ultralytics mediapipe opencv-python-headless -q
print("All installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.9 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 29.2 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 8.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# All installed!

# %%
import os

# Find where your files actually are
for root, dirs, files in os.walk("/kaggle/input"):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /kaggle/input/datasets/satyabratadas10/cv-server/video_processor.py
# /kaggle/input/datasets/satyabratadas10/cv-server/main.py

# %%
import shutil

shutil.copy("/kaggle/input/datasets/satyabratadas10/cv-server/video_processor.py", "/kaggle/working/video_processor.py")
shutil.copy("/kaggle/input/datasets/satyabratadas10/cv-server/main.py",            "/kaggle/working/main.py")

print("Files copied!")
# Out:
# Files copied!

# %%
import subprocess, time
from pyngrok import ngrok, conf

NGROK_TOKEN = "35uALBAWTmjvUTiujQneL2O151U_YR3q9jFkVmjf6Sk5SJYz"
conf.get_default().auth_token = NGROK_TOKEN

server = subprocess.Popen(
    ["python", "-m", "uvicorn", "main:app",
     "--host", "0.0.0.0", "--port", "8000"],
    cwd="/kaggle/working"
)

print("Waiting for models to load...")
time.sleep(20)

tunnel     = ngrok.connect(8000, "http")
PUBLIC_URL = tunnel.public_url

print("=" * 50)
print(f"SERVER LIVE!")
print(f"URL  : {PUBLIC_URL}")
print(f"Docs : {PUBLIC_URL}/docs")
print(f"Test : {PUBLIC_URL}/health")
print("=" * 50)
# Out:
# Waiting for models to load...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771731203.670285     176 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771731203.676961     176 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771731203.693622     176 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771731203.693653     176 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import time
print("Keeping alive — do not stop this cell!")
while True:
    time.sleep(1800)
    print("Still running...")
# Out:
# Keeping alive — do not stop this cell!
# Loading models — this takes ~30 seconds...
# VideoProcessor initialized.
# Models ready!
# INFO:     2001:468:300:800:355e:99f6:8bbe:aa6d:0 - "GET /health HTTP/1.1" 200 OK
# INFO:     2001:468:300:800:355e:99f6:8bbe:aa6d:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     2001:468:300:800:355e:99f6:8bbe:aa6d:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     2001:468:300:800:355e:99f6:8bbe:aa6d:0 - "GET /openapi.json HTTP/1.1" 200 OK
# W0000 00:00:1771731633.937727     227 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1771731633.972139     228 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...
