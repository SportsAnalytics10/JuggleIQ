# %%
# from cv.video_processor import VideoProcessor
# from pathlib import Path

# vp = VideoProcessor()
# Out:
# VideoProcessor initialized.

# %%
# input_dir = Path("data/input_videos")
# output_dir = Path("data/output_videos")

# output_dir.mkdir(parents=True, exist_ok=True)

# video_exts = {".mp4", ".mov", ".avi", ".mkv", ".webm"}

# for video_path in sorted(input_dir.iterdir()):
#     if video_path.suffix.lower() not in video_exts:
#         continue

#     out_path = output_dir / f"{video_path.stem}_A_annotated.mp4"

#     try:
#         vp.process_video(video_path, out_path)
#     except Exception as e:
#         print(f" Failed on {video_path.name}: {e}")
# Out:
# Video Info -> FPS: 30.07, Size: 1080x1920
# Processed 302 frames in 27.06 seconds
# Saved output to: /Users/satyabrata557/Desktop/Hackathon/Hacklytics/data/output_videos/IMG_5241_A_annotated.mp4
# Video Info -> FPS: 30.03, Size: 1080x1920
# Processed 343 frames in 31.35 seconds
# Saved output to: /Users/satyabrata557/Desktop/Hackathon/Hacklytics/data/output_videos/IMG_5244_A_annotated.mp4

# %%
import subprocess
result = subprocess.run(["python", "cv/video_processor.py"], capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
# Out:
# VideoProcessor initialized.
# Video Info -> FPS: 30.07, Size: 1080x1920
# Processed 302 frames in 28.06 seconds
# Saved output to: /Users/satyabrata557/Desktop/Hackathon/Hacklytics/data/output_videos/IMG_5241_A_annotated.mp4
# Video Info -> FPS: 30.03, Size: 1080x1920
# Processed 343 frames in 32.87 seconds
# Saved output to: /Users/satyabrata557/Desktop/Hackathon/Hacklytics/data/output_videos/IMG_5244_A_annotated.mp4
#
# /Users/satyabrata557/Desktop/Hackathon/Hacklytics/cv/video_processor.py:106: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   cx = int(pred[0])
# /Users/satyabrata557/Desktop/Hackathon/Hacklytics/cv/video_processor.py:107: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   cy = int(pred[1])
